# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.arange(0,100,3)
y = x*2
z = x**2

# %%
# Basic plot
plt.plot(x,z) 
plt.xlabel('X')
plt.ylabel('Y')
plt.title('TITLE')

# %%
# Subplots
plt.subplot(111)
plt.plot(x,y,'r')
plt.subplot(112)
plt.plot(x,z,'b')
