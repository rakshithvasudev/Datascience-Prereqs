# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.arange(0,100,3)
y = x*2
z = x**2

# %%
# Basic plot
plt.plot(x,z) 
plt.xlabel('X')
plt.ylabel('Y')
plt.title('TITLE')

# %%
# Subplots
plt.subplot(121)
plt.plot(x,y,'r')

plt.subplot(122)
plt.plot(x,z,'b')

# %%
# Object Oriented Approach
fig = plt.figure()    
axes = fig.add_axes([0.0,0.0,1,1]) # left, bottom, width, height (range 0 to 1)
axes.plot(x,z)
axes.set_xlabel('X Label')
axes.set_ylabel('Y Label')
axes.set_title('Title')

# %%
# subplots
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes1.set_xlabel("X Label")
axes1.set_ylabel("Y Label")
axes1.set_title("Title")
axes1.plot(y,z)


axes2 = fig.add_axes([0.15,0.5,0.4,0.3])
axes2.set_xlabel('Inner X')
axes2.set_xlabel('Inner Y')
axes2.set_title('Inner Title')
axes2.plot(z,x,'r')

# %%
# auto axes
fig, axes = plt.subplots()
axes.plot(y,x)

# %%
# auto axes 2
fig, axes = plt.subplots(1,3)

# %%
# Axes is an array of axes to plot on
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001B88D119DA0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001B88D211908>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001B88D229DA0>], dtype=object)

# %%
for axis in axes:
    axis.plot(x,z)
    axis.set_xlabel('X label')
    axis.set_xlabel('Y label')
    axis.set_title('Subplot')

fig
