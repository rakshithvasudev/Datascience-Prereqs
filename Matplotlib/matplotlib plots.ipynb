# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.arange(0,100,3)
y = x*2
z = x**2

# %%
# Out:
# (10, 50)

# %%
# Out:
# <function matplotlib.pyplot.tight_layout>
